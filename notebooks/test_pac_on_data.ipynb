# %%
import pandas as pd

# %%
csv_data = pd.read_csv('../data/hindi-train-low', sep='\t', names=['source', 'target', 'pos_info'])
del csv_data['pos_info']

# %%
# Extract objects and attributes from the dataset
from Concept_Learning import helper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8d4d0bae2f15> in <module>()
#       1 # Extract objects and attributes from the dataset
# ----> 2 from Concept_Learning import helper
#
# ModuleNotFoundError: No module named 'Concept_Learning'

# %%
hindi_data
# Out:
#            source                 target
# 0          सूंघना          सूंघ रहे होते
# 1           उबलना           उबल रहे होगे
# 2          पसीजना             पसीजी होगी
# 3           चाहना              चाहती थीं
# 4            कहना            कह रहे होते
# 5            बनना              बन रही थी
# 6         मरोड़ना           मरोड़ रहा हो
# 7           उछलना            उछलते होंगे
# 8        चोट करना          चोट करते होते
# 9           पढ़ना             पढ़ती होती
# 10          जानना               जानती थी
# 11          हंसना               हंसते हो
# 12          लिखना             लिख रहा था
# 13         निकलना            ये निकलेंगी
# 14          चबाना           चबा रही होती
# 15     प्रेम करना      प्रेम कर रही होती
# 16          पिटना            पिट रही थीं
# 17    अध्ययन करना         अध्ययन करते थे
# 18         समझाना            हम समझाएंगे
# 19          हारना             हार रही हो
# 20           पकना                पकते थे
# 21          बाटना                बाटए हो
# 22         सुनाना             सुनाई होती
# 23         अपनाना            अपना रही हो
# 24           रहना             रह रहे हैं
# 25    चुम्बन करना            चुम्बन करती
# 26          बजाना            बजा रही थीं
# 27         पिघलना              पिघली हूँ
# 28          हंसना              हंसती हूँ
# 29          फँसना               फँसा हूँ
# ..            ...                    ...
# 70           उठना            उठ रहे होते
# 71           उठना                उठी हैं
# 72         झाड़ना           झाड़ रही हों
# 73        ख़रीदना            ख़रीदा होगा
# 74      कंघी करना           कंघी करता था
# 75          बरसना             बरस रही है
# 76    चुम्बन करना       चुम्बन किया होता
# 77      चोरी करना          चोरी कियी थीं
# 78     शिकार करना          शिकार करता है
# 79     अपलोड करना          अपलोड करता है
# 80         चढ़ाना              चढ़ाती थी
# 81        मरोड़ना             मरोड़ती हो
# 82        लू करना          लू कियी होंगी
# 83        निखारना            निखारा होगा
# 84         पिघलना             पिघलते हों
# 85          कमाना              कमाता हूँ
# 86  शुक्रिया करना  शुक्रिया कर रही होंगी
# 87          चमकना             चमक रहा हो
# 88          बोलना             बोलती होगी
# 89  बर्दाश्त करना     बर्दाश्त किये होते
# 90        दोहराना           दोहरा रहे हो
# 91         छींकना            छींक रहे हो
# 92   स्थापित करना     स्थापित कर रही हों
# 93          घूमना               घूमा हूँ
# 94   डाउनलोड करना      डाउनलोड करती होगी
# 95      चोरी करना        चोरी कर रहे हैं
# 96   स्वप्न देखना         स्वप्न देखा है
# 97           हटना              हटती होती
# 98  ऐसी तैसी करना       ऐसी तैसी करती थी
# 99          बनाना                तू बनाए
#
# [100 rows x 2 columns]
